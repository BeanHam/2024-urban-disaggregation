# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
puma = np.load('puma_loss.npy')
nta = np.load('nta_loss.npy')
tract = np.load('tract_loss.npy')
block = np.load('block_loss.npy')
puma_rec = np.load('puma_rec_loss.npy')
nta_rec = np.load('nta_rec_loss.npy')
tract_rec = np.load('tract_rec_loss.npy')
plt.plot(puma, label='puma')
plt.plot(nta, label='nta')
plt.plot(tract, label='tract')
plt.plot(block, label='block')
plt.plot(puma_rec, label='puma_rec')
plt.plot(nta_rec, label='nta_rec')
plt.plot(tract_rec, label='tract_rec')
plt.legend()
pass

# %%
puma[-1]*20, nta[-1]*5, tract[-1]*2, block[-1]
# Out:
# (0.0003230766770781208,
#  0.00019496942897633074,
#  0.0001445434692612716,
#  0.00015925931053942293)

# %%
puma_rec[-1]*20, nta_rec[-1]*5, tract_rec[-1]*2
# Out:
# (0.0003593661277229634, 0.00018191006177999429, 0.00014258021398916719)
