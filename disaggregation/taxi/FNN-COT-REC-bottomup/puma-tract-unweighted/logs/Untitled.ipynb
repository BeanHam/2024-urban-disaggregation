# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
puma = np.load('puma_loss.npy')
nta = np.load('nta_loss.npy')
tract = np.load('tract_loss.npy')
puma_rec = np.load('puma_rec_loss.npy')
nta_rec = np.load('nta_rec_loss.npy')
plt.plot(puma, label='puma')
plt.plot(nta, label='nta')
plt.plot(tract, label='tract')
plt.plot(puma_rec, label='puma_rec')
plt.plot(nta_rec, label='nta_rec')
plt.legend()
pass

# %%
puma[-1]*10, nta[-1]*5, tract[-1]*2
# Out:
# (3.0865881271975334e-05, 0.00016831545344068646, 0.00012524536126513777)

# %%
puma_rec[-1]*10, nta_rec[-1]*5
# Out:
# (7.071632854399459e-05, 0.00012385284853541043)

# %%
import numpy as np
import matplotlib.pyplot as plt

puma = np.load('puma_loss.npy')
nta = np.load('nta_loss.npy')
tract = np.load('tract_loss.npy')
block = np.load('block_loss.npy')
extreme = np.load('extreme_loss.npy')
puma_rec = np.load('puma_rec_loss.npy')
nta_rec = np.load('nta_rec_loss.npy')
tract_rec = np.load('tract_rec_loss.npy')
block_rec = np.load('block_rec_loss.npy')
plt.plot(puma, label='puma')
plt.plot(nta, label='nta')
plt.plot(tract, label='tract')
plt.plot(block, label='block')
plt.plot(extreme, label='extreme')
plt.plot(puma_rec, label='puma_rec')
plt.plot(nta_rec, label='nta_rec')
plt.plot(tract_rec, label='tract_rec')
plt.plot(block_rec, label='block_rec')
plt.legend()
pass

puma[-1]*20, nta[-1]*5, tract[-1]*2, block[-1], extreme[-1]

puma_rec[-1]*20, nta_rec[-1]*5, tract_rec[-1]*2, block_rec[-1]
