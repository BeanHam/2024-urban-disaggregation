# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
max_v = 9740.0
puma = np.load('puma_loss.npy')*max_v
nta = np.load('nta_loss.npy')*max_v
tract = np.load('tract_loss.npy')*max_v
block = np.load('block_loss.npy')*max_v
extreme = np.load('extreme_loss.npy')*max_v
puma_rec = np.load('puma_rec_loss.npy')*max_v
nta_rec = np.load('nta_rec_loss.npy')*max_v
tract_rec = np.load('tract_rec_loss.npy')*max_v
block_rec = np.load('block_rec_loss.npy')*max_v
plt.plot(puma, label='puma')
plt.plot(nta, label='nta')
plt.plot(tract, label='tract')
plt.plot(block, label='block')
plt.plot(extreme, label='extreme')
plt.plot(puma_rec, label='puma_rec')
plt.plot(nta_rec, label='nta_rec')
plt.plot(tract_rec, label='tract_rec')
plt.plot(block_rec, label='block_rec')
plt.legend()
pass

# %%
puma[-1], nta[-1], tract[-1], block[-1], extreme[-1]
# Out:
# (0.10730912741075387,
#  0.3272553152475173,
#  0.7155070652325584,
#  1.7627619169088933,
#  2.236700000764525)

# %%
puma[-1]*20, nta[-1]*5, tract[-1]*2, block[-1], extreme[-1]
# Out:
# (2.1461825482150774,
#  1.6362765762375864,
#  1.4310141304651167,
#  1.7627619169088933,
#  2.236700000764525)

# %%
puma_rec[-1]*20, nta_rec[-1]*5, tract_rec[-1]*2, block_rec[-1]
# Out:
# (1.6057289383838655,
#  1.4314192133517945,
#  1.6269560218879466,
#  1.5560003475894613)
