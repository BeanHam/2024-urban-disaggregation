# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
puma = np.load('puma_loss.npy')
nta = np.load('nta_loss.npy')
puma_rec = np.load('puma_rec_loss.npy')
plt.plot(puma, label='puma')
plt.plot(nta, label='nta')
plt.plot(puma_rec, label='puma_rec')
plt.legend()
pass

# %%
puma[-1],puma_rec[-1], nta[-1]
# Out:
# (5.003717260905596e-07, 1.4821699269431106e-06, 2.3081248766045057e-05)

# %%
puma[-1]*20, puma_rec[-1]*20, nta[-1]*5
# Out:
# (1.0007434521811193e-05, 2.964339853886221e-05, 0.00011540624383022528)
