# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
nta = np.load('nta_loss.npy')
len(nta)
# Out:
# 788

# %%
20/(788+50)
# Out:
# 0.02386634844868735

# %%
puma = np.load('puma_loss.npy')
nta = np.load('nta_loss.npy')
plt.plot(puma, label='puma')
plt.plot(nta, label='nta')
plt.legend()
pass

# %%
puma[-1]*20, nta[-1]*5
# Out:
# (5.119028548880931e-06, 0.00011601688375616357)
